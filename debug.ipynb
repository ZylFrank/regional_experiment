# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/zyl/Documents/区试数据/国家区试表型青贮玉米/格式化表头/2008/2008年国家青贮玉米区域试验品质分析结果.csv")
df
# Out:
#     试验年份   生态分组      品种名称  中性洗涤纤维含量(%)  酸性洗涤纤维含量(%)  粗蛋白含量(%) 纤维品质等级
# 0   2008  青贮玉米组      春贮1号        63.55        36.91      8.76     四级
# 1   2008  青贮玉米组  YA748219        59.45        33.52      8.22     四级
# 2   2008  青贮玉米组     华青800        45.85        25.10      8.88     二级
# 3   2008  青贮玉米组     豫青玉1号        39.82        17.70     11.54     一级
# 4   2008  青贮玉米组      曲辰九号        51.43        27.62     11.25     三级
# 5   2008  青贮玉米组      珍禾3号        49.34        27.17      8.54     二级
# 6   2008  青贮玉米组      阜青1号        43.02        22.33     10.28     一级
# 7   2008  青贮玉米组   SAU0601        38.51        20.30      8.75     一级
# 8   2008  青贮玉米组      丹青1号        52.83        30.03     10.09     三级
# 9   2008  青贮玉米组      成青83        43.84        23.38     10.32     一级
# 10  2008  青贮玉米组    新饲玉12号        45.30        23.92      9.25     二级
# 11  2008  青贮玉米组      渝青24        47.86        24.17     10.71     二级
# 12  2008  青贮玉米组    北育0805        45.97        23.37      8.95     二级
# ...

# %%
a = df[["试验年份","生态分组","品种名称"]+[]].copy()
b = df[["试验年份","生态分组","品种名称"]+["中性洗涤纤维含量(%)"]].copy()
c = df[["试验年份","生态分组","品种名称"]+["中性洗涤纤维含量(%)", "酸性洗涤纤维含量(%)"]].copy()

# %%
import uuid
str(uuid.uuid4())
# Out:
# '3f81a201-7208-4304-ae61-6b9973e6c664'
